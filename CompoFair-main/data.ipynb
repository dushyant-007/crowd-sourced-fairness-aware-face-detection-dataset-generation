# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from data import gen_img_batch

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('treebank')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
text = word_tokenize("And now for something completely different")
sent = nltk.pos_tag(text)
print(nltk.ne_chunk(sent, binary=True))
# Out:
# (S And/CC now/RB for/IN something/NN completely/RB different/JJ)
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\akgo1\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\akgo1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\akgo1\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\akgo1\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\akgo1\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
imgs = gen_img_batch()
print(imgs)
plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(imgs):
    plt.subplot(len(imgs) / columns + 1, columns, i + 1)
    plt.imshow(mpimg.imread(image))
# Out:
# ['./dataset/celeba/images\\2\\000515.jpg', './dataset/celeba/images\\3\\000623.jpg', './dataset/celeba/images\\1\\000346.jpg']
# <ipython-input-5-79c4c6110446>:6: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(len(imgs) / columns + 1, columns, i + 1)
